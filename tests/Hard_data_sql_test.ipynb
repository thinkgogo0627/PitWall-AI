# %%
import sqlite3
import pandas as pd

# 1. 테스트용 DB 연결 (파일로 생성됨)
db_path = "/mnt/c/Users/hojin/OneDrive/바탕 화면/Kaggle/PitWall-AI/data/f1_test_for_sql.db"
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

conn.commit()
print(f"🔧 '{db_path}' 생성 및 연결 완료.\n")

# --- 3. (선택) 데이터가 비어있으니, 확인용 더미 데이터 1개씩 넣어보기 ---
# (SQL 테스트를 위해 실제 데이터를 넣으려면 어제 만든 update_db.py를 실행하는 게 가장 빠릅니다)
# Out:
# 🔧 '/mnt/c/Users/hojin/OneDrive/바탕 화면/Kaggle/PitWall-AI/data/f1_test_for_sql.db' 생성 및 연결 완료.

# %%
query = "SELECT * FROM race_results WHERE RaceID LIKE '2025%'"
df_race_result = pd.read_sql(query, conn)
display(df_race_result)
# Out:
#                          RaceID  Year    Circuit Driver         TeamName  \
# 0   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    NOR          McLaren
# 1   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    ANT         Mercedes
# 2   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    VER  Red Bull Racing
# 3   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    RUS         Mercedes
# 4   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    PIA          McLaren
# 5   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    BEA     Haas F1 Team
# 6   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    LAW     Racing Bulls
# 7   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    HAD     Racing Bulls
# 8   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    HUL      Kick Sauber
# 9   2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    GAS           Alpine
# 10  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    ALB         Williams
# 11  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    OCO     Haas F1 Team
# 12  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    SAI         Williams
# 13  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    ALO     Aston Martin
# 14  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    COL           Alpine
# 15  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    STR     Aston Martin
# 16  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    TSU  Red Bull Racing
# 17  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    HAM          Ferrari
# 18  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    LEC          Ferrari
# 19  2025_São_Paulo_Grand_Prix_R  2025  Sao paulo    BOR      Kick Sauber
#
#     Position  GridPosition  Points    Status
# 0        1.0           1.0    25.0  Finished
# 1        2.0           2.0    18.0  Finished
# 2        3.0          19.0    15.0  Finished
# 3        4.0           6.0    12.0  Finished
# 4        5.0           4.0    10.0  Finished
# 5        6.0           8.0     8.0  Finished
# 6        7.0           7.0     6.0  Finished
# 7        8.0           5.0     4.0  Finished
# 8        9.0          10.0     2.0  Finished
# 9       10.0           9.0     1.0  Finished
# 10      11.0          12.0     0.0  Finished
# 11      12.0          20.0     0.0  Finished
# 12      13.0          15.0     0.0  Finished
# 13      14.0          11.0     0.0  Finished
# 14      15.0          16.0     0.0  Finished
# 15      16.0          14.0     0.0  Finished
# 16      17.0          17.0     0.0  Finished
# 17      18.0          13.0     0.0   Retired
# 18      19.0           3.0     0.0   Retired
# 19      20.0          18.0     0.0   Retired

# %%
query = "SELECT * FROM lap_times WHERE RaceID LIKE '2025%'"
df_lap_times = pd.read_sql(query, conn)
display(df_lap_times)
# Out:
#                            RaceID Driver  LapNumber  Stint Compound  TyreLife  \
# 0     2025_São_Paulo_Grand_Prix_R    VER        1.0    1.0     HARD       1.0
# 1     2025_São_Paulo_Grand_Prix_R    VER        2.0    1.0     HARD       2.0
# 2     2025_São_Paulo_Grand_Prix_R    VER        3.0    1.0     HARD       3.0
# 3     2025_São_Paulo_Grand_Prix_R    VER        4.0    1.0     HARD       4.0
# 4     2025_São_Paulo_Grand_Prix_R    VER        5.0    1.0     HARD       5.0
# ...                           ...    ...        ...    ...      ...       ...
# 1246  2025_São_Paulo_Grand_Prix_R    BEA       67.0    3.0   MEDIUM      31.0
# 1247  2025_São_Paulo_Grand_Prix_R    BEA       68.0    3.0   MEDIUM      32.0
# 1248  2025_São_Paulo_Grand_Prix_R    BEA       69.0    3.0   MEDIUM      33.0
# 1249  2025_São_Paulo_Grand_Prix_R    BEA       70.0    3.0   MEDIUM      34.0
# 1250  2025_São_Paulo_Grand_Prix_R    BEA       71.0    3.0   MEDIUM      35.0
#
#       FreshTyre LapTime_Sec Sector1_Sec  Sector2_Sec  Sector3_Sec  IsAccurate
# 0             1      87.191        None       39.288       17.131           0
# 1             1     120.413       21.32       75.859       23.234           0
# 2             1     109.007      21.675       58.682       28.650           0
# 3             1      106.62      25.318       59.748       21.554           0
# 4             1     107.889      30.078       50.463       27.348           0
# ...         ...         ...         ...          ...          ...         ...
# 1246          0      73.694       18.91       37.919       16.865           1
# 1247          0      73.952      19.063       37.896       16.993           1
# 1248          0      73.813      18.995       37.811       17.007           1
# 1249          0      74.317      19.096       37.954       17.267           1
# 1250          0      75.252      19.626       38.346       17.280           1
#
# [1251 rows x 12 columns]

# %%
query = "SELECT * FROM lap_times WHERE RaceID LIKE '2025%' AND Driver = 'VER'"
df_lap_times = pd.read_sql(query, conn)
display(df_lap_times)
# Out:
#                          RaceID Driver  LapNumber  Stint Compound  TyreLife  \
# 0   2025_São_Paulo_Grand_Prix_R    VER        1.0    1.0     HARD       1.0
# 1   2025_São_Paulo_Grand_Prix_R    VER        2.0    1.0     HARD       2.0
# 2   2025_São_Paulo_Grand_Prix_R    VER        3.0    1.0     HARD       3.0
# 3   2025_São_Paulo_Grand_Prix_R    VER        4.0    1.0     HARD       4.0
# 4   2025_São_Paulo_Grand_Prix_R    VER        5.0    1.0     HARD       5.0
# ..                          ...    ...        ...    ...      ...       ...
# 66  2025_São_Paulo_Grand_Prix_R    VER       67.0    4.0     SOFT      13.0
# 67  2025_São_Paulo_Grand_Prix_R    VER       68.0    4.0     SOFT      14.0
# 68  2025_São_Paulo_Grand_Prix_R    VER       69.0    4.0     SOFT      15.0
# 69  2025_São_Paulo_Grand_Prix_R    VER       70.0    4.0     SOFT      16.0
# 70  2025_São_Paulo_Grand_Prix_R    VER       71.0    4.0     SOFT      17.0
#
#     FreshTyre LapTime_Sec Sector1_Sec  Sector2_Sec  Sector3_Sec  IsAccurate
# 0           1      87.191        None       39.288       17.131           0
# 1           1     120.413       21.32       75.859       23.234           0
# 2           1     109.007      21.675       58.682       28.650           0
# 3           1      106.62      25.318       59.748       21.554           0
# 4           1     107.889      30.078       50.463       27.348           0
# ..        ...         ...         ...          ...          ...         ...
# 66          1      73.463      18.825       37.919       16.719           1
# 67          1      73.536      18.697       38.075       16.764           1
# 68          1      73.472       18.66       38.091       16.721           1
# 69          1       73.84       18.71       38.227       16.903           1
# 70          1      73.699      18.807       38.150       16.742           1
#
# [71 rows x 12 columns]

# %%
## 정확한 랩 에서, 랩의 중반 페이스
## (초반은 어차피 타이어 온도때문에 데이터 딱히 무의미, 후반은 Lico를 하는 경우같은거 제외 시 어차피 풀푸시)
## 타이어 종류 별 랩타임 비교
## 트랙마다 56랩, 71랩 다르니까 중간만 대충 계산

'''
SELECT 
    Driver, 
    Compound, 
    COUNT(*) as Laps_Run,
    ROUND(AVG(LapTime_Sec), 3) as Avg_Pace,
    MIN(LapTime_Sec) as Best_Lap
FROM lap_times
WHERE RaceID = '2023_Las_Vegas_R' 
  AND IsAccurate = 'True'
  AND LapNumber BETWEEN MIN(LapNumber) + (0.15 * Max(LapNumber)) AND MAX(Lapnumber) - (0.15 * Max(LapNumber))
GROUP BY Driver, Compound
ORDER BY Driver, Avg_Pace ASC;
'''

# %%
## 순위 상승폭 체크
## DNF, DNS, DSQ 제외

'''
SELECT 
    Driver, 
    TeamName,
    GridPosition, 
    Position as FinishPosition,
    (GridPosition - Position) as Positions_Gained -- 양수면 순위 상승
FROM race_results
WHERE RaceID = '2023_Las_Vegas_R' AND Status = 'Finished'
ORDER BY Positions_Gained DESC;
'''

# %%
## 드라이버들의 스틴트별 타이어 컴파운드와 랩 타임 평균

'''
SELECT
    Driver,
    Compound,
